# %%
from selenium import webdriver
from selenium.webdriver import ActionChains
from selenium.webdriver.common.by import By
from selenium.webdriver.support import expected_conditions as EC
from selenium.webdriver.support.ui import WebDriverWait
from selenium.common.exceptions import TimeoutException,ElementNotInteractableException, NoSuchElementException

#from webdriver_manager.chrome import ChromeDriverManager
from bs4 import BeautifulSoup as bs
import pandas as pd
import time

# 設定 Chrome 瀏覽器的選項
options = webdriver.ChromeOptions()
options.add_argument("--start-maximized") # Chrome 瀏覽器在啟動時最大化視窗
options.add_argument("--incognito") # 無痕模式
options.add_argument("--disable-popup-blocking") # 停用 Chrome 的彈窗阻擋功能。

# 建立 Chrome 瀏覽器物件
driver = webdriver.Chrome(options=options)
driver.implicitly_wait(10) # 隱性等待
driver.get("https://today.line.me/tw/v2/movie/incinemas/playing")

# 初始化 ActionChains
action = ActionChains(driver)

# %% [markdown]
# ### 利用 While Loop 與判斷式實作自動化網頁無限滾動
#
# 本小節將展示如何透過無限迴圈 (`while True`) 搭配條件判斷式 (`if`)，來應對現代網頁常見的**懶加載 (Lazy Loading)** 機制。透過模擬人類向下滾動網頁的行為，我們可以持續觸發 AJAX 請求，直到抓取完整頁面資料。
#
# **核心執行步驟：**
# 1. **狀態追蹤**：設定 `last_count` 變數，用於紀錄前一次滾動後的資料總筆數。
# 2. **終止條件判斷**：在迴圈內抓取當前頁面的元素總數 (`current_count`)。若兩者數量相等 (`current_count == last_count`)，即代表網頁已抵達底部，無新資料載入，此時執行 `break` 終止迴圈。
# 3. **動態滾動觸發**：若尚有新資料，則定位出當前清單中的「最後一個元素」，並運用 `ActionChains` 將視窗滾動至該元素位置，迫使網頁載入後續資料。

# %%
# 初始化前一次抓取的電影數量
last_count = 0
# 所有電影元素:
movie_list_whole = []

# 持續滾動葉面，直到沒有新資料載入為止
while True:
    # 1. 取得目前頁面上的所有電影元素
    movie_list_whole = driver.find_elements(By.CSS_SELECTOR, 'div.detailListItem.movieListing-movie')
    print(len(movie_list_whole))
    


    # 第一個迴圈 current_count: last_count:
    # 第二個迴圈 current_count: last_count:
    # 第三個迴圈 current_count: last_count:
    # 第四個迴圈 current_count: last_count:

    # 判斷新資料是否有載入
    if last_count == len(movie_list_whole):
        break


    # 找出目前清單的「最後一個元素」
    last_element = movie_list_whole[-1]

    # 使用 ActionChain 滾動到最後一個元素 (action.scroll_to_element(參數).perform())
    # 這會讓瀏覽器將視窗滾動到該元素出現的位置，會觸發 AJAX (Lazyloading)
    action.scroll_to_element(last_element).perform()


    # 等待資料載入
    time.sleep(2)


    # 更新 last_count
    last_count = len(movie_list_whole)


    # 第一個迴圈 current_count: last_count:
    # 第二個迴圈 current_count: last_count:
    # 第三個迴圈 current_count: last_count:
# Out:
# 20
# 30
# 40
# 50
# 60
# 70
# 76
# 76

# %% [markdown]
# ### 利用enumerate 將以取得的電影資訊篩選出我們要的內容存入清單內
#
#
# #### 一、 核心教學目標：利用 `enumerate` 篩選並儲存資料
# 在處理多筆資料時，**「利用 `enumerate` 將已取得的電影資訊篩選出我們要的內容存入清單內」** 是一個非常標準且優雅的設計模式。`enumerate` 不僅能讓我們遍歷元素集合（`movie_list_whole`），還能同時自動生成索引值（`i`），這對於追蹤爬取進度、記錄日誌（Log）或在發生例外錯誤時進行除錯都極具價值。
#
# #### 二、 Selenium 關鍵取值方法
# 在上述的迴圈中，我們主要練習兩種最常用的 Selenium 資料萃取屬性與方法：
#
# 1.  **`.text` 屬性**：
#     * **用途**：取得兩個 HTML 標籤之間包含的純文字內容。
#     * **應用場景**：當我們需要標題、評分、分級等直接顯示在網頁上的可見文字時使用。例如從 `<h2>標題</h2>` 中提取「標題」。
# 2.  **`.get_attribute('屬性名稱')` 方法**：
#     * **用途**：取得 HTML 標籤內的特定屬性值。
#     * **應用場景**：網頁中有許多重要資訊不會直接顯示為文字，而是隱藏在標籤屬性中。例如超連結的網址（`href`）、圖片的來源（`src`），或是表單元素的名稱（`name`）。在此範例中，我們利用 `.get_attribute('href')` 來精準提取時刻表的目標網址。

# %%
import pprint
# 建立一個空的容器，放置電影資訊
movie_list = []

# 遍歷所有電影元素並提取詳細的電影資訊
for i, element in enumerate(movie_list_whole):
    try:
        # 取得電影標題
        '''
        CSS Selector:
        h2.detailListItem-title.header.header--sm.header--primary.header--ellipsis1
        '''
        title = element.find_element(By.CSS_SELECTOR, 'h2.detailListItem-title.header.header--sm.header--primary.header--ellipsis1').text
        

        # 取得評分
        '''
        CSS Selector :
        span.iconInfo-text.text.text--f.text--secondary.text--regular
        '''
        grading = element.find_element(By.CSS_SELECTOR, 'span.iconInfo-text.text.text--f.text--secondary.text--regular').text
        

        # 取得分級 
        '''
        CSS Selector :
        span.glnBadge-text.text.text--fNarrow.text--secondary.text--regular
        '''
        # 初始化分級元素
        classing = element.find_element(By.CSS_SELECTOR, 'span.glnBadge-text.text.text--fNarrow.text--secondary.text--regular').text
        

        # 取得時刻表連結
        #利用 .get_attribute('href') 來精準提取時刻表的目標網址
        '''
        CSS Selector:
        a.detailListItem-bookingButton
        '''
        linking = element.find_element(By.CSS_SELECTOR, 'a.detailListItem-bookingButton').get_attribute('href')
       

    # 若找不到元素，程式不會報錯，而是執行此區塊
    # 可以選擇裡面填寫 pass 或紀錄log
    except NoSuchElementException:
        pass
    print(f"{i+1}, {title}, 評分: {grading}, 分級: {classing}, 網址: {linking}")

    

    # 將單一電影的所有屬性打包為字典 (Dictionary)，並附加至 movie_list 串列的最尾端
    # 建立鍵值對 (Key-Value Pair) 以對應萃取出的變數
    movie_dict = {"title": title, "grading": grading, "classing": classing, "linking": linking}
    movie_list.append(movie_dict)

    
pprint.pprint(movie_list)
# Out:
# 1, 穿著Prada的惡魔2, 評分: 8.6, 分級: 普遍級, 網址: https://today.line.me/tw/v3/movie/rmvVX2w/1
# 2, 超級瑪利歐銀河電影版, 評分: 8.7, 分級: 普遍級, 網址: https://today.line.me/tw/v3/movie/BEQD020/1
# 3, 麥可傑克森, 評分: 9.5, 分級: 保護級, 網址: https://today.line.me/tw/v3/movie/9mLzWqe/1
# 4, 祭弒, 評分: 3.8, 分級: 輔15級, 網址: https://today.line.me/tw/v3/movie/2D7RMvN/1
# 5, 關於我轉生變成史萊姆這檔事 劇場版 蒼海之淚篇, 評分: 8.5, 分級: 保護級, 網址: https://today.line.me/tw/v3/movie/OpMnGyj/1
# 6, 動物農莊, 評分: 9.4, 分級: 普遍級, 網址: https://today.line.me/tw/v3/movie/WB6nGPQ/1
# 7, 死亡賭局, 評分: 8.7, 分級: 輔12級, 網址: https://today.line.me/tw/v3/movie/j78VvVz/1
# 8, 狸想世界, 評分: 9.2, 分級: 普遍級, 網址: https://today.line.me/tw/v3/movie/vXVJwB0/1
# 9, 李克寧 墓乃伊, 評分: 7.6, 分級: 限制級, 網址: https://today.line.me/tw/v3/movie/0MNL20p/1
# 10, 極限返航, 評分: 9.1, 分級: 保護級, 網址: https://today.line.me/tw/v3/movie/9mll09x/1
# 11, 伴我一生，感謝你, 評分: 10, 分級: 普遍級, 網址: https://today.line.me/tw/v3/movie/vXOo7Zl/1
# 12, 終極搜查, 評分: 9.7, 分級: 輔15級, 網址: https://today.line.me/tw/v3/movie/JP1Wxey/1
# 13, 死亡之握：鬼牽手, 評分: 8.4, 分級: 輔15級, 網址: https://today.line.me/tw/v3/movie/RB8P27j/1
# 14, 殺木池：鬼水禁地, 評分: 8.5, 分級: 輔12級, 網址: https://today.line.me/tw/v3/movie/oqYr6v6/1
# 15, 抓馬戀人, 評分: 8.5, 分級: 輔15級, 網址: https://today.line.me/tw/v3/movie/1DyxPWp/1
# 16, 0時盜數, 評分: 9.0, 分級: 輔12級, 網址: https://today.line.me/tw/v3/movie/Gg5ko3Z/1
# 17, ONE OK ROCK DETOX JAPAN TOUR 2025 AT NISSAN STADIUM IN CINEMAS, 評分: 10, 分級: 普遍級, 網址: https://today.line.me/tw/v3/movie/0MGNE8D/1
# 18, 後座力, 評分: 0.0, 分級: 限制級, 網址: https://today.line.me/tw/v3/movie/pekawgw/1
# 19, 催眠麥克風, 評分: 9.0, 分級: 普遍級, 網址: https://today.line.me/tw/v3/movie/kEoZJv1/1
# 20, MEZZO FORTE 次強音, 評分: 0.0, 分級: 限制級, 網址: https://today.line.me/tw/v3/movie/yzkKZ7G/1
# 21, 陽光女子合唱團, 評分: 9.0, 分級: 輔12級, 網址: https://today.line.me/tw/v3/movie/1Dnwjm3/1
# 22, 愛在每一天, 評分: 0.0, 分級: 保護級, 網址: https://today.line.me/tw/v3/movie/zNwNWoD/1
# 23, 最後的棋局, 評分: 0.0, 分級: 輔12級, 網址: https://today.line.me/tw/v3/movie/zNwo2M5/1
# 24, 屍咒還魂, 評分: 0.0, 分級: 輔12級, 網址: https://today.line.me/tw/v3/movie/MLq9VgM/1
# 25, 空之境界劇場版：第七章 殺人考察(後), 評分: 9.9, 分級: 輔15級, 網址: https://today.line.me/tw/v3/movie/60QGWzX/1
# 26, 空姐復仇記, 評分: 0.0, 分級: 普遍級, 網址: https://today.line.me/tw/v3/movie/MLoYKlD/1
# 27, 雙囍, 評分: 9.2, 分級: 普遍級, 網址: https://today.line.me/tw/v3/movie/PGNQZRo/1
# 28, 劇場版 銀河特急 Milky☆Subway, 評分: 9.2, 分級: 保護級, 網址: https://today.line.me/tw/v3/movie/eL5WGyD/1
# 29, No Good！歐吉桑, 評分: 8.4, 分級: 普遍級, 網址: https://today.line.me/tw/v3/movie/vXM6jD3/1
# 30, 竊取本書者將會…, 評分: 10, 分級: 普遍級, 網址: https://today.line.me/tw/v3/movie/QwYgVNp/1
# 31, 大濛, 評分: 9.0, 分級: 保護級, 網址: https://today.line.me/tw/v3/movie/9m7LoZm/1
# 32, 咆哮山莊, 評分: 7.9, 分級: 輔15級, 網址: https://today.line.me/tw/v3/movie/1Dr9WeM/1
# 33, 劇場版「暗殺教室」: 我們的時光, 評分: 8.8, 分級: 保護級, 網址: https://today.line.me/tw/v3/movie/rmQ79vn/1
# 34, 關鍵公敵, 評分: 8.7, 分級: 輔12級, 網址: https://today.line.me/tw/v3/movie/wJMaKDY/1
# 35, 科學新娘！, 評分: 9.5, 分級: 輔15級, 網址: https://today.line.me/tw/v3/movie/oq7QKzy/1
# 36, A KITE 風箏, 評分: 10, 分級: 限制級, 網址: https://today.line.me/tw/v3/movie/Vx8LoNR/1
# 37, 你是不會當樹嗎, 評分: 8.0, 分級: 輔12級, 網址: https://today.line.me/tw/v3/movie/l2GvemB/1
# 38, 巧虎電影《勇氣之歌》, 評分: 0.0, 分級: 普遍級, 網址: https://today.line.me/tw/v3/movie/Ya80jEB/1
# 39, 夏日大作戰(全新4K修復版), 評分: 10, 分級: 普遍級, 網址: https://today.line.me/tw/v3/movie/pe9YP56/1
# 40, #我要說出真相, 評分: 0.0, 分級: 輔12級, 網址: https://today.line.me/tw/v3/movie/1DMXJ7M/1
# 41, 大檢察官, 評分: 0.0, 分級: 保護級, 網址: https://today.line.me/tw/v3/movie/yzjBBno/1
# 42, 自殺通告, 評分: 7.8, 分級: 輔12級, 網址: https://today.line.me/tw/v3/movie/YavOK1M/1
# 43, 哈姆奈特, 評分: 9.0, 分級: 輔12級, 網址: https://today.line.me/tw/v3/movie/2DjzpE6/1
# 44, 驚聲尖叫7, 評分: 6.8, 分級: 輔15級, 網址: https://today.line.me/tw/v3/movie/aGQNqPW/1
# 45, 捕風追影, 評分: 9.5, 分級: 輔12級, 網址: https://today.line.me/tw/v3/movie/XY5KMw0/1
# 46, 藤本樹17-26：PART 1, 評分: 0.0, 分級: 輔12級, 網址: https://today.line.me/tw/v3/movie/RBk1Xpj/1
# 47, 藤本樹17-26：PART 2, 評分: 0.0, 分級: 輔12級, 網址: https://today.line.me/tw/v3/movie/pekzryN/1
# 48, 再見UFO, 評分: 10, 分級: 保護級, 網址: https://today.line.me/tw/v3/movie/2D3k26a/1
# 49, 末路雙嬌, 評分: 7.0, 分級: 輔15級, 網址: https://today.line.me/tw/v3/movie/Za5Q1Gj/1
# 50, 犯罪101, 評分: 7.6, 分級: 輔12級, 網址: https://today.line.me/tw/v3/movie/PGNa1EV/1
# 51, 魅影巨星, 評分: 4.7, 分級: 輔12級, 網址: https://today.line.me/tw/v3/movie/mWMgVyr/1
# 52, 海街日記, 評分: 9.8, 分級: 普遍級, 網址: https://today.line.me/tw/v3/movie/EXeDZqn/1
# 53, 星與月是天上的洞, 評分: 8.0, 分級: 限制級, 網址: https://today.line.me/tw/v3/movie/0MGyZLz/1
# 54, 邊境奇譚, 評分: 0.0, 分級: 輔12級, 網址: https://today.line.me/tw/v3/movie/WB65W8R/1
# 55, 誰想當老大, 評分: 4.6, 分級: 輔12級, 網址: https://today.line.me/tw/v3/movie/eLOy8PG/1
# 56, 六張臉：狂言師的舞台人生, 評分: 0.0, 分級: 普遍級, 網址: https://today.line.me/tw/v3/movie/l28pPZL/1
# 57, 小雨愛蜜莉, 評分: 0.0, 分級: 普遍級, 網址: https://today.line.me/tw/v3/movie/wJ3V2jY/1
# 58, 3670, 評分: 0.0, 分級: 輔15級, 網址: https://today.line.me/tw/v3/movie/NvGrB0Z/1
# 59, 如月車站2, 評分: 9.2, 分級: 輔12級, 網址: https://today.line.me/tw/v3/movie/Gg5ZjgR/1
# 60, 泰殺歌后戰, 評分: 9.0, 分級: 保護級, 網址: https://today.line.me/tw/v3/movie/aG5RZOO/1
# 61, 穿越地獄之門, 評分: 5.3, 分級: 輔15級, 網址: https://today.line.me/tw/v3/movie/nX8l69g/1
# 62, 蠱降, 評分: 8.7, 分級: 限制級, 網址: https://today.line.me/tw/v3/movie/3NYNGyr/1
# 63, 高雄有顆藍寶石, 評分: 9.5, 分級: 保護級, 網址: https://today.line.me/tw/v3/movie/7Nqmz3M/1
# 64, 生命之詩(4K數位修復版), 評分: 0.0, 分級: 保護級, 網址: https://today.line.me/tw/v3/movie/9mqan3V/1
# 65, 尋秦記Plus+多元宇宙版, 評分: 10, 分級: 輔12級, 網址: https://today.line.me/tw/v3/movie/5y2nxXr/1
# 66, 星光王子 Your Endless Call! 一起閃耀！Prism☆Tours, 評分: 10, 分級: 普遍級, 網址: https://today.line.me/tw/v3/movie/NvRmW0Z/1
# 67, 秒速5公分(導演特別映像版), 評分: 10, 分級: 普遍級, 網址: https://today.line.me/tw/v3/movie/8nq2jyq/1
# 68, 弒婚遊戲：2度開局, 評分: 8.6, 分級: 限制級, 網址: https://today.line.me/tw/v3/movie/vX36aaj/1
# 69, 你罪乖, 評分: 0.0, 分級: 輔15級, 網址: https://today.line.me/tw/v3/movie/mWMXzpw/1
# 70, 總統的蛋糕, 評分: 10, 分級: 保護級, 網址: https://today.line.me/tw/v3/movie/5yqQ33y/1
# 71, 機動戰士鋼彈 閃光的哈薩威 喀耳刻的魔女, 評分: 7.0, 分級: 普遍級, 網址: https://today.line.me/tw/v3/movie/gz8wQ6z/1
# 72, 邪降：覺醒, 評分: 8.7, 分級: 限制級, 網址: https://today.line.me/tw/v3/movie/JPq32k3/1
# 73, 深度安靜, 評分: 6.0, 分級: 保護級, 網址: https://today.line.me/tw/v3/movie/nX8VEZy/1
# 74, 舞林殺手, 評分: 0.0, 分級: 保護級, 網址: https://today.line.me/tw/v3/movie/7Nq3X6r/1
# 75, 人生海海, 評分: 0.0, 分級: 保護級, 網址: https://today.line.me/tw/v3/movie/oqP567o/1
# 76, 心機特務, 評分: 10, 分級: 保護級, 網址: https://today.line.me/tw/v3/movie/0MGPg0G/1
# [{'classing': '普遍級',
#   'grading': '8.6',
#   'linking': 'https://today.line.me/tw/v3/movie/rmvVX2w/1',
#   'title': '穿著Prada的惡魔2'},
#  {'classing': '普遍級',
#   'grading': '8.7',
#   'linking': 'https://today.line.me/tw/v3/movie/BEQD020/1',
#   'title': '超級瑪利歐銀河電影版'},
#  {'classing': '保護級',
#   'grading': '9.5',
#   'linking': 'https://today.line.me/tw/v3/movie/9mLzWqe/1',
#   'title': '麥可傑克森'},
#  {'classing': '輔15級',
#   'grading': '3.8',
#   'linking': 'https://today.line.me/tw/v3/movie/2D7RMvN/1',
#   'title': '祭弒'},
#  {'classing': '保護級',
#   'grading': '8.5',
#   'linking': 'https://today.line.me/tw/v3/movie/OpMnGyj/1',
#   'title': '關於我轉生變成史萊姆這檔事 劇場版 蒼海之淚篇'},
#  {'classing': '普遍級',
#   'grading': '9.4',
#   'linking': 'https://today.line.me/tw/v3/movie/WB6nGPQ/1',
#   'title': '動物農莊'},
#  {'classing': '輔12級',
#   'grading': '8.7',
#   'linking': 'https://today.line.me/tw/v3/movie/j78VvVz/1',
#   'title': '死亡賭局'},
#  {'classing': '普遍級',
#   'grading': '9.2',
#   'linking': 'https://today.line.me/tw/v3/movie/vXVJwB0/1',
#   'title': '狸想世界'},
#  {'classing': '限制級',
#   'grading': '7.6',
#   'linking': 'https://today.line.me/tw/v3/movie/0MNL20p/1',
#   'title': '李克寧 墓乃伊'},
#  {'classing': '保護級',
#   'grading': '9.1',
#   'linking': 'https://today.line.me/tw/v3/movie/9mll09x/1',
#   'title': '極限返航'},
#  {'classing': '普遍級',
#   'grading': '10',
#   'linking': 'https://today.line.me/tw/v3/movie/vXOo7Zl/1',
#   'title': '伴我一生，感謝你'},
#  {'classing': '輔15級',
#   'grading': '9.7',
#   'linking': 'https://today.line.me/tw/v3/movie/JP1Wxey/1',
#   'title': '終極搜查'},
#  {'classing': '輔15級',
#   'grading': '8.4',
#   'linking': 'https://today.line.me/tw/v3/movie/RB8P27j/1',
#   'title': '死亡之握：鬼牽手'},
#  {'classing': '輔12級',
#   'grading': '8.5',
#   'linking': 'https://today.line.me/tw/v3/movie/oqYr6v6/1',
#   'title': '殺木池：鬼水禁地'},
#  {'classing': '輔15級',
#   'grading': '8.5',
#   'linking': 'https://today.line.me/tw/v3/movie/1DyxPWp/1',
#   'title': '抓馬戀人'},
#  {'classing': '輔12級',
#   'grading': '9.0',
#   'linking': 'https://today.line.me/tw/v3/movie/Gg5ko3Z/1',
#   'title': '0時盜數'},
#  {'classing': '普遍級',
#   'grading': '10',
#   'linking': 'https://today.line.me/tw/v3/movie/0MGNE8D/1',
#   'title': 'ONE OK ROCK DETOX JAPAN TOUR 2025 AT NISSAN STADIUM IN CINEMAS'},
#  {'classing': '限制級',
#   'grading': '0.0',
#   'linking': 'https://today.line.me/tw/v3/movie/pekawgw/1',
#   'title': '後座力'},
#  {'classing': '普遍級',
#   'grading': '9.0',
#   'linking': 'https://today.line.me/tw/v3/movie/kEoZJv1/1',
#   'title': '催眠麥克風'},
#  {'classing': '限制級',
#   'grading': '0.0',
#   'linking': 'https://today.line.me/tw/v3/movie/yzkKZ7G/1',
#   'title': 'MEZZO FORTE 次強音'},
#  {'classing': '輔12級',
#   'grading': '9.0',
#   'linking': 'https://today.line.me/tw/v3/movie/1Dnwjm3/1',
#   'title': '陽光女子合唱團'},
#  {'classing': '保護級',
#   'grading': '0.0',
#   'linking': 'https://today.line.me/tw/v3/movie/zNwNWoD/1',
#   'title': '愛在每一天'},
#  {'classing': '輔12級',
#   'grading': '0.0',
#   'linking': 'https://today.line.me/tw/v3/movie/zNwo2M5/1',
#   'title': '最後的棋局'},
#  {'classing': '輔12級',
#   'grading': '0.0',
#   'linking': 'https://today.line.me/tw/v3/movie/MLq9VgM/1',
#   'title': '屍咒還魂'},
#  {'classing': '輔15級',
#   'grading': '9.9',
#   'linking': 'https://today.line.me/tw/v3/movie/60QGWzX/1',
#   'title': '空之境界劇場版：第七章 殺人考察(後)'},
#  {'classing': '普遍級',
#   'grading': '0.0',
#   'linking': 'https://today.line.me/tw/v3/movie/MLoYKlD/1',
#   'title': '空姐復仇記'},
#  {'classing': '普遍級',
#   'grading': '9.2',
#   'linking': 'https://today.line.me/tw/v3/movie/PGNQZRo/1',
#   'title': '雙囍'},
#  {'classing': '保護級',
#   'grading': '9.2',
#   'linking': 'https://today.line.me/tw/v3/movie/eL5WGyD/1',
#   'title': '劇場版 銀河特急 Milky☆Subway'},
#  {'classing': '普遍級',
#   'grading': '8.4',
#   'linking': 'https://today.line.me/tw/v3/movie/vXM6jD3/1',
#   'title': 'No Good！歐吉桑'},
#  {'classing': '普遍級',
#   'grading': '10',
#   'linking': 'https://today.line.me/tw/v3/movie/QwYgVNp/1',
#   'title': '竊取本書者將會…'},
#  {'classing': '保護級',
#   'grading': '9.0',
#   'linking': 'https://today.line.me/tw/v3/movie/9m7LoZm/1',
#   'title': '大濛'},
#  {'classing': '輔15級',
#   'grading': '7.9',
#   'linking': 'https://today.line.me/tw/v3/movie/1Dr9WeM/1',
#   'title': '咆哮山莊'},
#  {'classing': '保護級',
#   'grading': '8.8',
#   'linking': 'https://today.line.me/tw/v3/movie/rmQ79vn/1',
#   'title': '劇場版「暗殺教室」: 我們的時光'},
#  {'classing': '輔12級',
#   'grading': '8.7',
#   'linking': 'https://today.line.me/tw/v3/movie/wJMaKDY/1',
#   'title': '關鍵公敵'},
#  {'classing': '輔15級',
#   'grading': '9.5',
#   'linking': 'https://today.line.me/tw/v3/movie/oq7QKzy/1',
#   'title': '科學新娘！'},
#  {'classing': '限制級',
#   'grading': '10',
#   'linking': 'https://today.line.me/tw/v3/movie/Vx8LoNR/1',
#   'title': 'A KITE 風箏'},
#  {'classing': '輔12級',
#   'grading': '8.0',
#   'linking': 'https://today.line.me/tw/v3/movie/l2GvemB/1',
#   'title': '你是不會當樹嗎'},
#  {'classing': '普遍級',
#   'grading': '0.0',
#   'linking': 'https://today.line.me/tw/v3/movie/Ya80jEB/1',
#   'title': '巧虎電影《勇氣之歌》'},
#  {'classing': '普遍級',
#   'grading': '10',
#   'linking': 'https://today.line.me/tw/v3/movie/pe9YP56/1',
#   'title': '夏日大作戰(全新4K修復版)'},
#  {'classing': '輔12級',
#   'grading': '0.0',
#   'linking': 'https://today.line.me/tw/v3/movie/1DMXJ7M/1',
#   'title': '#我要說出真相'},
#  {'classing': '保護級',
#   'grading': '0.0',
#   'linking': 'https://today.line.me/tw/v3/movie/yzjBBno/1',
#   'title': '大檢察官'},
#  {'classing': '輔12級',
#   'grading': '7.8',
#   'linking': 'https://today.line.me/tw/v3/movie/YavOK1M/1',
#   'title': '自殺通告'},
#  {'classing': '輔12級',
#   'grading': '9.0',
#   'linking': 'https://today.line.me/tw/v3/movie/2DjzpE6/1',
#   'title': '哈姆奈特'},
#  {'classing': '輔15級',
#   'grading': '6.8',
#   'linking': 'https://today.line.me/tw/v3/movie/aGQNqPW/1',
#   'title': '驚聲尖叫7'},
#  {'classing': '輔12級',
#   'grading': '9.5',
#   'linking': 'https://today.line.me/tw/v3/movie/XY5KMw0/1',
#   'title': '捕風追影'},
#  {'classing': '輔12級',
#   'grading': '0.0',
#   'linking': 'https://today.line.me/tw/v3/movie/RBk1Xpj/1',
#   'title': '藤本樹17-26：PART 1'},
#  {'classing': '輔12級',
#   'grading': '0.0',
#   'linking': 'https://today.line.me/tw/v3/movie/pekzryN/1',
#   'title': '藤本樹17-26：PART 2'},
#  {'classing': '保護級',
#   'grading': '10',
#   'linking': 'https://today.line.me/tw/v3/movie/2D3k26a/1',
#   'title': '再見UFO'},
#  {'classing': '輔15級',
#   'grading': '7.0',
#   'linking': 'https://today.line.me/tw/v3/movie/Za5Q1Gj/1',
#   'title': '末路雙嬌'},
#  {'classing': '輔12級',
#   'grading': '7.6',
#   'linking': 'https://today.line.me/tw/v3/movie/PGNa1EV/1',
#   'title': '犯罪101'},
#  {'classing': '輔12級',
#   'grading': '4.7',
#   'linking': 'https://today.line.me/tw/v3/movie/mWMgVyr/1',
#   'title': '魅影巨星'},
#  {'classing': '普遍級',
#   'grading': '9.8',
#   'linking': 'https://today.line.me/tw/v3/movie/EXeDZqn/1',
#   'title': '海街日記'},
#  {'classing': '限制級',
#   'grading': '8.0',
#   'linking': 'https://today.line.me/tw/v3/movie/0MGyZLz/1',
#   'title': '星與月是天上的洞'},
#  {'classing': '輔12級',
#   'grading': '0.0',
#   'linking': 'https://today.line.me/tw/v3/movie/WB65W8R/1',
#   'title': '邊境奇譚'},
#  {'classing': '輔12級',
#   'grading': '4.6',
#   'linking': 'https://today.line.me/tw/v3/movie/eLOy8PG/1',
#   'title': '誰想當老大'},
#  {'classing': '普遍級',
#   'grading': '0.0',
#   'linking': 'https://today.line.me/tw/v3/movie/l28pPZL/1',
#   'title': '六張臉：狂言師的舞台人生'},
#  {'classing': '普遍級',
#   'grading': '0.0',
#   'linking': 'https://today.line.me/tw/v3/movie/wJ3V2jY/1',
#   'title': '小雨愛蜜莉'},
#  {'classing': '輔15級',
#   'grading': '0.0',
#   'linking': 'https://today.line.me/tw/v3/movie/NvGrB0Z/1',
#   'title': '3670'},
#  {'classing': '輔12級',
#   'grading': '9.2',
#   'linking': 'https://today.line.me/tw/v3/movie/Gg5ZjgR/1',
#   'title': '如月車站2'},
#  {'classing': '保護級',
#   'grading': '9.0',
#   'linking': 'https://today.line.me/tw/v3/movie/aG5RZOO/1',
#   'title': '泰殺歌后戰'},
#  {'classing': '輔15級',
#   'grading': '5.3',
#   'linking': 'https://today.line.me/tw/v3/movie/nX8l69g/1',
#   'title': '穿越地獄之門'},
#  {'classing': '限制級',
#   'grading': '8.7',
#   'linking': 'https://today.line.me/tw/v3/movie/3NYNGyr/1',
#   'title': '蠱降'},
#  {'classing': '保護級',
#   'grading': '9.5',
#   'linking': 'https://today.line.me/tw/v3/movie/7Nqmz3M/1',
#   'title': '高雄有顆藍寶石'},
#  {'classing': '保護級',
#   'grading': '0.0',
#   'linking': 'https://today.line.me/tw/v3/movie/9mqan3V/1',
#   'title': '生命之詩(4K數位修復版)'},
#  {'classing': '輔12級',
#   'grading': '10',
#   'linking': 'https://today.line.me/tw/v3/movie/5y2nxXr/1',
#   'title': '尋秦記Plus+多元宇宙版'},
#  {'classing': '普遍級',
#   'grading': '10',
#   'linking': 'https://today.line.me/tw/v3/movie/NvRmW0Z/1',
#   'title': '星光王子 Your Endless Call! 一起閃耀！Prism☆Tours'},
#  {'classing': '普遍級',
#   'grading': '10',
#   'linking': 'https://today.line.me/tw/v3/movie/8nq2jyq/1',
#   'title': '秒速5公分(導演特別映像版)'},
#  {'classing': '限制級',
#   'grading': '8.6',
#   'linking': 'https://today.line.me/tw/v3/movie/vX36aaj/1',
#   'title': '弒婚遊戲：2度開局'},
#  {'classing': '輔15級',
#   'grading': '0.0',
#   'linking': 'https://today.line.me/tw/v3/movie/mWMXzpw/1',
#   'title': '你罪乖'},
#  {'classing': '保護級',
#   'grading': '10',
#   'linking': 'https://today.line.me/tw/v3/movie/5yqQ33y/1',
#   'title': '總統的蛋糕'},
#  {'classing': '普遍級',
#   'grading': '7.0',
#   'linking': 'https://today.line.me/tw/v3/movie/gz8wQ6z/1',
#   'title': '機動戰士鋼彈 閃光的哈薩威 喀耳刻的魔女'},
#  {'classing': '限制級',
#   'grading': '8.7',
#   'linking': 'https://today.line.me/tw/v3/movie/JPq32k3/1',
#   'title': '邪降：覺醒'},
#  {'classing': '保護級',
#   'grading': '6.0',
#   'linking': 'https://today.line.me/tw/v3/movie/nX8VEZy/1',
#   'title': '深度安靜'},
#  {'classing': '保護級',
#   'grading': '0.0',
#   'linking': 'https://today.line.me/tw/v3/movie/7Nq3X6r/1',
#   'title': '舞林殺手'},
#  {'classing': '保護級',
#   'grading': '0.0',
#   'linking': 'https://today.line.me/tw/v3/movie/oqP567o/1',
#   'title': '人生海海'},
#  {'classing': '保護級',
#   'grading': '10',
#   'linking': 'https://today.line.me/tw/v3/movie/0MGPg0G/1',
#   'title': '心機特務'}]

# %%
'''
等等會用到
'''
FULL_STAR_PATH = 'M12 18.344l-5.81 3.609c-.147.091-.34.046-.43-.1-.043-.07-.057-.152-.04-.23l1.469-6.96-5.09-4.736c-.126-.118-.133-.316-.016-.442.052-.056.122-.091.198-.099l6.746-.68 2.684-6.513c.066-.16.249-.235.408-.17.077.032.138.094.17.17l2.684 6.514 6.746.68c.172.017.297.17.28.342-.008.075-.043.146-.099.198l-5.09 4.736 1.47 6.96c.036.169-.072.334-.24.37-.08.017-.161.002-.23-.04L12 18.343z'
HALF_STAR_PATH = 'M12.12 2.024c.076.031.137.093.169.17l2.684 6.513 6.746.68c.172.017.297.17.28.342-.008.075-.043.146-.099.198l-5.09 4.736 1.47 6.96c.036.169-.072.334-.24.37-.08.017-.161.002-.23-.04L12 18.343l-5.81 3.61c-.147.091-.34.046-.43-.1-.043-.07-.057-.152-.04-.23l1.469-6.96-5.09-4.736c-.126-.118-.133-.316-.016-.442.052-.056.122-.091.198-.099l6.746-.68 2.684-6.513c.066-.16.249-.235.408-.17zM12 6.463v9.651l3.662 2.275-.925-4.383 3.316-3.086-4.398-.443L12 6.463z'

# 初始化一個主列表來存放評論資料
all_reviews_data = []


    # 取的單一電影的場次連結
for element in movie_list:
    link = element["linking"]

    # 取得電影名稱
    title = element["title"]
    print(f"正在爬取電影: {title}")

    # 前往該電影的詳細頁面
    driver.get(element["linking"])

    try:
        '''
        一、挑戰(ㄧ): 訪問詳細頁面時，等待最多 10 秒，直到「網友短評」這個分頁元素可以點擊
            教學目標:
                - 設定並練習使用顯式等待 (Explicit Wait)的策略
            學員實作:
                - 建立一個等待物件，設定最長的等待時間為 10 秒
                - 後續所有的等待操作都須遵守這個超時設定
        '''
        wait = WebDriverWait(driver, 10)
 

        '''
        二、挑戰(二): 點擊「網友短評」這個分頁元素
           教學目標:
                - 當有多個元素共用同一個 CSS選擇器字串，要等到這些元素均出現，且「網友短評」這個分頁元素可以點擊
            學員實作:
                - 將 CSS 選擇器字串存放到一個變數中，方便後續維護與修改
                註 : CSS_Selector : 'a.ltcp-link.tabLink.movie.css-1hq811z'
                - 撰寫邏輯使程式等待直到所有符合選擇器的分頁連結元素都出現在頁面中      
        '''


        # Selenium 的 expected_condition 模組中，所有與尋找元素相關的條件類別，其均設計為接收 「一個」參數
        # 而該參數被嚴格定義為一個包含兩個字串原物的元組(Tuple)
        # 因此當我們利用By策略時，傳入presence_of_all_elements_located這個方法的參數須為Tuple(By.CSS_SELECTOR, tab_selector)
        tab_selector = 'a.ltcp-link.tabLink.movie.css-1hq811z'
        elements = wait.until(EC.presence_of_all_elements_located((By.CSS_SELECTOR, tab_selector)))
        
        '''
        「如果你問老師說 : 那如果 10 秒內都沒有等到呢?」
        :「那就會拋出 TimeoutException 異常，直行將跳轉到對應的 except 區塊」
        '''

        # 檢查分頁元素的數量
        if len(elements) < 3:
            print(f"電影: {title} 的分頁數量不足，所以跳過...")
            continue
       

        # 取得「網友短評」分頁元素
        review_tab = elements[-1]
  
 
        # 等到元素可以被點擊，後進行點擊
        wait.until(EC.element_to_be_clickable(review_tab)).click()
        

    # 捕捉在尋找或點擊「網友短評」元素過程中，最常發生的三種特定例外狀況：
    # 1. TimeoutException: 顯式等待（Explicit Wait）超過設定時間上限，目標元素仍未載入或不可見。
    # 2. IndexError: 嘗試透過索引值取出列表元素（例如 elements[0]）時，發現列表為空，意味著 DOM 樹中不存在符合選擇器的節點。
    # 3. ElementNotInteractableException: 目標元素雖然存在於 DOM 樹中，但可能被其他浮動元素（如廣告、彈出視窗）遮擋，或屬性為隱藏（Hidden），導致 WebDriver 無法執行點擊動作。
    except(TimeoutException, IndexError, ElementNotInteractableException) as e:
        print(f"電影: {title} 的網友短評無法互動，因為{e}")
        continue
    
    # 恭喜，如果你在這邊還活著的話，你已經可以順路進入到網友短評
    # 觀察每個「網友短評」，會發現依然要向下滾動網頁使瀏覽器載入新的評論

    # 初始化前一次抓取網友短評的數量
    last_count = 0
  
    
    while True:
        # 1. 取得目前頁面上所有的評論
        # CSS_Selector : div.css-hnvcda
        comment_list_whole = driver.find_elements(By.CSS_SELECTOR, 'div.css-hnvcda')
        current_count = len(comment_list_whole)

        # 2. 終止條件 : 判斷是否還有新資料載入
        # 如果目前數量等於上次數量，代表網頁已不再載入新內容，迴圈結束
        if current_count == last_count:
            break

        # 3. 鎖定目標 : 找出目前清單中的「最後一個」評論元素
        last_element = comment_list_whole[-1]

        # 4. 使用ActionChains 滾動到最後一個元素
        action.scroll_to_element(last_element).perform()

        # 5. 等待載入
        time.sleep(2)

        # 6.更新狀態 : 將目前的數量記錄下來，供下一輪比對
        last_count = current_count
    # 遍歷當前頁面的所有評論
    for comment_node in comment_list_whole:
        try:
            # 擷取星星數量
            # CSS_Selector : div[class=ratingStar] path
            star_paths = comment_node.find_elements(By.CSS_SELECTOR, 'div.ratingStar path')

            # 初始化星星數量
            star = 0

            # 判定星星為整顆/半顆，並且計算星星數量
            for path in star_paths:
                # 取得 path 的 d 屬性值
                path_data = path.get_attribute('d')
                if path_data == FULL_STAR_PATH:
                    star = star + 1
                elif path_data == HALF_STAR_PATH:
                    star += 0.5



            # 擷取評論的內容文字賦值給comment_text
            # CSS_Selector : span.css-xcrf5c
            comment_text = comment_node.find_element(By.CSS_SELECTOR, 'span.css-12gpsi').text


            #將擷取到的評論資料整理成字典，存入總清單中
            all_reviews_data.append({
                "title": title,
                "star": star,
                "comments": comment_text
            })
        except NoSuchElementException:
            print(f"電影: {title}的某則評論不完整，故跳過...")
            continue

   

# 將先前爬蟲迴圈中收集到包含多個字典(Dictionary)的串列(List) 'all_reviews_data'
# 作為引數傳入 pd.DataFrame() 建構子中。
# 此操作會將該串列轉換為二維的 Pandas DataFrame 物件，並將記憶體參考賦值給變數 'df'
df = pd.DataFrame(all_reviews_data)

driver.quit()
# Out:
# 正在爬取電影: 穿著Prada的惡魔2
# 正在爬取電影: 超級瑪利歐銀河電影版
# 正在爬取電影: 麥可傑克森
# 正在爬取電影: 祭弒
# 正在爬取電影: 關於我轉生變成史萊姆這檔事 劇場版 蒼海之淚篇
# 正在爬取電影: 動物農莊
# 正在爬取電影: 死亡賭局
# 正在爬取電影: 狸想世界
# 正在爬取電影: 李克寧 墓乃伊
# 正在爬取電影: 極限返航
# 正在爬取電影: 伴我一生，感謝你
# 正在爬取電影: 終極搜查
# 正在爬取電影: 死亡之握：鬼牽手
# 正在爬取電影: 殺木池：鬼水禁地
# 正在爬取電影: 抓馬戀人
# 正在爬取電影: 0時盜數
# 正在爬取電影: ONE OK ROCK DETOX JAPAN TOUR 2025 AT NISSAN STADIUM IN CINEMAS
# 正在爬取電影: 後座力
# 正在爬取電影: 催眠麥克風
# 正在爬取電影: MEZZO FORTE 次強音
# 正在爬取電影: 陽光女子合唱團
# 正在爬取電影: 愛在每一天
# 正在爬取電影: 最後的棋局
# 正在爬取電影: 屍咒還魂
# 正在爬取電影: 空之境界劇場版：第七章 殺人考察(後)
# 正在爬取電影: 空姐復仇記
# 正在爬取電影: 雙囍
# 正在爬取電影: 劇場版 銀河特急 Milky☆Subway
# 正在爬取電影: No Good！歐吉桑
# 正在爬取電影: 竊取本書者將會…
# 正在爬取電影: 大濛
# 正在爬取電影: 咆哮山莊
# 正在爬取電影: 劇場版「暗殺教室」: 我們的時光
# 正在爬取電影: 關鍵公敵
# 正在爬取電影: 科學新娘！
# 正在爬取電影: A KITE 風箏
# 正在爬取電影: 你是不會當樹嗎
# 正在爬取電影: 巧虎電影《勇氣之歌》
# 正在爬取電影: 夏日大作戰(全新4K修復版)
# 正在爬取電影: #我要說出真相
# 正在爬取電影: 大檢察官
# 正在爬取電影: 自殺通告
# 正在爬取電影: 哈姆奈特
# 正在爬取電影: 驚聲尖叫7
# 正在爬取電影: 捕風追影
# 正在爬取電影: 藤本樹17-26：PART 1
# 正在爬取電影: 藤本樹17-26：PART 2
# 正在爬取電影: 再見UFO
# 正在爬取電影: 末路雙嬌
# 正在爬取電影: 犯罪101
# 正在爬取電影: 魅影巨星
# 正在爬取電影: 海街日記
# 正在爬取電影: 星與月是天上的洞
# 正在爬取電影: 邊境奇譚
# 正在爬取電影: 誰想當老大
# 正在爬取電影: 六張臉：狂言師的舞台人生
# 正在爬取電影: 小雨愛蜜莉
# 正在爬取電影: 3670
# 正在爬取電影: 如月車站2
# 正在爬取電影: 泰殺歌后戰
# 正在爬取電影: 穿越地獄之門
# 正在爬取電影: 蠱降
# 正在爬取電影: 高雄有顆藍寶石
# 正在爬取電影: 生命之詩(4K數位修復版)
# 正在爬取電影: 尋秦記Plus+多元宇宙版
# 正在爬取電影: 星光王子 Your Endless Call! 一起閃耀！Prism☆Tours
# 正在爬取電影: 秒速5公分(導演特別映像版)
# 正在爬取電影: 弒婚遊戲：2度開局
# 正在爬取電影: 你罪乖
# 正在爬取電影: 總統的蛋糕
# 正在爬取電影: 機動戰士鋼彈 閃光的哈薩威 喀耳刻的魔女
# 正在爬取電影: 邪降：覺醒
# 正在爬取電影: 深度安靜
# 正在爬取電影: 舞林殺手
# 正在爬取電影: 人生海海
# 正在爬取電影: 心機特務

# %% [markdown]
# 存成 csv 檔案

# %%
# 檢視資料表前 5 列 (Rows)，確認資料是否正確載入且行名 (Columns) 對齊無誤
print("資料表前 5 列:")
print(df.head())
# Out:
# 資料表前 5 列:
#          title  star                                           comments
# 0  穿著Prada的惡魔2   5.0                             我覺得非常好看，演員演技出色，劇情也非常棒。
# 1  穿著Prada的惡魔2   5.0            比起米蘭達的氣場，\n小安的理想感，\n我更喜歡艾蜜莉.布朗的「高級時尚假掰」
# 2  穿著Prada的惡魔2   5.0                                           第二集一樣很好看
# 3  穿著Prada的惡魔2   5.0                就像見老朋友的感覺，滿滿的回憶，內容很豐富更多了深度，非常好看的續集。
# 4  穿著Prada的惡魔2   4.0  第二集有蠻多第一集的經典元素啦…\n沒有不好看也沒有很好看\n就沒有超越第一集，有一part...

# %%
# 3. 檢視數值型資料行的敘述性統計 (如：評分的最大值、最小值、平均值)
print("\n數值資料敘述性統計:")
print(df.describe())
# Out:
# 數值資料敘述性統計:
#              star
# count  828.000000
# mean     4.440821
# std      1.105718
# min      0.500000
# 25%      4.500000
# 50%      5.000000
# 75%      5.000000
# max      5.000000

# %% [markdown]
# **`encoding='utf-8-sig'`**
#
# ：
# **字元編碼參數**
#
# 。這是針對繁體中文語系至關重要的設定。一般寫入文字檔常使用
#
# ```
# 'utf-8'
# ```
#
# ，但在微軟的 Excel 軟體中直接開啟普通的 UTF-8 檔案時，經常會出現中文亂碼。加上
#
# ```
# -sig
# ```
#
# 後，Pandas 會在檔案開頭寫入
#
# **BOM（Byte Order Mark，位元組順序記號）**
#
# ，藉此強制作業系統與 Excel 識別該檔案為 UTF-8 編碼，確保中文字元得以正確渲染。

# %%
#  將清理或確認無誤的資料匯出為 CSV 檔案進行持久化儲存
# 參數說明：index=False 避免將 DataFrame 預設的整數索引寫入檔案；encoding='utf-8-sig' 確保繁體中文在 Excel 中不會出現亂碼
df.to_csv('movie_reviews.csv', index=False, encoding='utf-8-sig')
