# %% [markdown]
# #### 使用 requests 函式庫發送 GET 請求並解析回應

# %%
import requests

# 1. 對目標網址發送 GET 請求，並將完整的伺服器回應(一個封裝了請求結果的物件)存入 'res' 變數中
res = requests.get('https://httpbin.org/get')

# 我們一起觀察這個物件有甚麼屬性和功能
print(res)

# 2. 檢查回應狀態碼(status_code)，200 代表請求成功
# 狀態碼可以告知我們請求的處理狀態
print(res.status_code)

# 3. 查看 requests 函式庫自動判斷的編碼格式(encoding)
#    httpbin 預設使用 utf-8，所以 requests 通常能正確判斷
print(res.encoding)

# (備註) 如果自動判斷錯誤導致 res.text 出現亂碼，
# 可取消以下這行的註解，手動指定正確的編碼
# res.encoding = 'utf-8'


# 4. 輸出解碼後的文字內容 (text;此處 httpbin 回傳的是 JSON 格式的文字)
print("\n--- Response Text ---")
print(res.text)
# Out:
# <Response [200]>
# 200
# utf-8
#
# --- Response Text ---
# {
#   "args": {},
#   "headers": {
#     "Accept": "*/*",
#     "Accept-Encoding": "gzip, deflate",
#     "Host": "httpbin.org",
#     "User-Agent": "python-requests/2.33.1",
#     "X-Amzn-Trace-Id": "Root=1-69e883af-7be2dc1b1b36d4940a92a75a"
#   },
#   "origin": "1.160.9.130",
#   "url": "https://httpbin.org/get"
# }

# %% [markdown]
# 在 GET 請求中附加查詢參數 (Query String)

# %%
# 1. 定義一個字典來存放要附加到 URL 的查詢參數 (Query String)
#    requests 函式庫會自動將其轉換為 "?key1=value1&key2=value2" 的格式
my_params = {"key1": "value1", "key2": "value2"}

# 2. 在 GET 請求中，透過 params 參數傳遞我們的字典
#    requests 會自動將 my_params 附加到 URL 後面
res = requests.get('https://httpbin.org/get', params=my_params)

# 3. 透過 res.url 屬性，可以觀察到 requests 實際發出的完整 URL
#    這是一個很好的除錯技巧，用來確認我們的參數是否正確附加
print(f"Final URL: {res.url}")

# 4. 輸出伺服器回應的內容
#    觀察回傳的 JSON 中 "args" 欄位，可以看到伺服器確實收到了我們的參數
print("\n--- Response Text ---")
print(res.text)
# Out:
# Final URL: https://httpbin.org/get?key1=value1&key2=value2
#
# --- Response Text ---
# {
#   "args": {
#     "key1": "value1",
#     "key2": "value2"
#   },
#   "headers": {
#     "Accept": "*/*",
#     "Accept-Encoding": "gzip, deflate",
#     "Host": "httpbin.org",
#     "User-Agent": "python-requests/2.33.1",
#     "X-Amzn-Trace-Id": "Root=1-69e884c8-5a0bf73e2163f59a4ec24fa2"
#   },
#   "origin": "1.160.9.130",
#   "url": "https://httpbin.org/get?key1=value1&key2=value2"
# }

# %% [markdown]
# 在 GET 請求中自訂標頭 (Custom Headers)

# %%
# 1. 定義一個字典來存放自訂的請求標頭 (Request Headers)
#    'user-agent' 是最常用的一個，用來告訴伺服器我們是什麼樣的瀏覽器或客戶端。
# 'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/99.0.4844.82 Safari/537.36'
my_headers = {'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/99.0.4844.82 Safari/537.36'}

# 2. 在 GET 請求中，透過 headers 參數傳遞我們的自訂標頭字典
res = requests.get('https://httpbin.org/get', headers=my_headers)

# 3. 輸出伺服器回應的內容
#    觀察回傳的 JSON 中 "headers" -> "User-Agent" 欄位，
#    可以看到它已經變成了我們剛剛自訂的內容，而不是 requests 函式庫的預設值。
print("--- Response Text ---")
print(res.text)
# Out:
# --- Response Text ---
# {
#   "args": {},
#   "headers": {
#     "Accept": "*/*",
#     "Accept-Encoding": "gzip, deflate",
#     "Host": "httpbin.org",
#     "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/99.0.4844.82 Safari/537.36",
#     "X-Amzn-Trace-Id": "Root=1-69e88439-4253afb45654356a360366f9"
#   },
#   "origin": "1.160.9.130",
#   "url": "https://httpbin.org/get"
# }

# %% [markdown]
# 在 GET 請求中夾帶 Cookie

# %%
# 1. 定義一個字典來存放要傳送的 Cookie
#    字典的鍵 (key) 是 Cookie 的名稱，值 (value) 是其內容。
my_cookies = {
    "first_cookie" : "hello"
}

# 2. 在 GET 請求中，透過 cookies 參數傳遞我們的自訂 Cookie 字典
#    requests 函式庫會自動將這個字典轉換成正確的 Cookie 標頭格式。
res = requests.get('https://httpbin.org/get', cookies=my_cookies)

# 3. 輸出伺服器回應的內容
#    觀察回傳的 JSON 中 "headers" -> "Cookie" 欄位，
#    可以看到它包含了 "first_cookie=hello; second_cookie=world"，證明 Cookie 已成功送出。
print("--- Response Text ---")
print(res.text)
# Out:
# --- Response Text ---
# {
#   "args": {},
#   "headers": {
#     "Accept": "*/*",
#     "Accept-Encoding": "gzip, deflate",
#     "Cookie": "first_cookie=hello",
#     "Host": "httpbin.org",
#     "User-Agent": "python-requests/2.33.1",
#     "X-Amzn-Trace-Id": "Root=1-69e8847f-6c9f469c51a341131d8f2c4f"
#   },
#   "origin": "1.160.9.130",
#   "url": "https://httpbin.org/get"
# }

# %% [markdown]
# 解析 API 回傳的 JSON 資料

# %%
import requests
import json

# 1. 定義要請求的 API 網址
#    這個網址來自 OPENTIX，用於獲取節目列表，並透過查詢參數指定頁數和每頁筆數
# Example url : https://csm.api.opentix.life/programs?page=44&rowCount=10
url = "https://csm.api.opentix.life/programs?page=44&rowCount=10"

# 2. 發送 GET 請求
res = requests.get(url)


# 3. 觀察伺服器回傳的原始內容
#    res.text 是一個純文字字串，雖然看起來有結構，但程式無法直接操作
print(res.text[:300])
print(type(res.text))


# 4. 將 JSON 格式的字串轉換為 Python 物件 (字典)
#    方法一：使用 json 模組 (較通用)
#    obj = json.loads(res.text) 
#    方法二：使用 requests 內建的 .json() 方法 (更簡潔，推薦)
obj = json.loads(res.text)
print(obj)
print(type(obj))

# requests 的 .json()
obj2 = res.json()
print(obj2)
print(type(obj2))


# 5. 解析並提取資料
#    轉換後，我們可以像操作 Python 字典一樣，用中括號 [] 搭配鍵 (key) 來存取巢狀資料
# print(obj['result']) # 檢視 'result' 鍵對應的內容
# print(obj['result']['data']) # 進一步檢視 'result' -> 'data' 的內容


# 6. 遍歷資料列表
#    'data' 鍵對應的值是一個列表 (list)，其中包含了多個節目資訊 (字典)
# 取'節目名稱'與'類別'
# Out:
# {"requestId":"fd5ef0e5-1482-4430-995a-62998889944a","result":{"nextPage":45,"data":[{"id":"2034547591404400641","departmentId":0,"name":"2026 衛武營音樂營&歐洲銅管之聲 教師音樂會《自由揮灑》","displayCategory":"音樂","imageUrl":"https://s3.resource.opentix.life/upload/program/17739187905838NTnluHUhs.png","startDateTime":178
# <class 'str'>
# {'requestId': 'fd5ef0e5-1482-4430-995a-62998889944a', 'result': {'nextPage': 45, 'data': [{'id': '2034547591404400641', 'departmentId': 0, 'name': '2026 衛武營音樂營&歐洲銅管之聲 教師音樂會《自由揮灑》', 'displayCategory': '音樂', 'imageUrl': 'https://s3.resource.opentix.life/upload/program/17739187905838NTnluHUhs.png', 'startDateTime': 1783769400, 'endDateTime': 1783775100, 'maxPrice': 1200, 'minPrice': 500, 'filmRating': '普遍級', 'cities': ['高雄'], 'events': [{'id': '2034553038721073153', 'startDateTime': 1783769400, 'endDateTime': 1783775100}]}, {'id': '2034877460146262017', 'departmentId': 0, 'name': '2026瑞光樂集《追憶多瑙河畔》', 'displayCategory': '音樂', 'imageUrl': 'https://s3.resource.opentix.life/upload/program/1773987455836rXKOgL6SCg.jpeg', 'startDateTime': 1781850600, 'endDateTime': 1782219600, 'maxPrice': 800, 'minPrice': 300, 'ageRestriction': '5歲 (以上)', 'cities': ['臺中', '臺北'], 'events': [{'id': '2034878251594113024', 'startDateTime': 1781850600, 'endDateTime': 1781856000}, {'id': '2034910848353263617', 'startDateTime': 1782214200, 'endDateTime': 1782219600}]}, {'id': '2035245605008674817', 'departmentId': 0, 'name': '【崑劇】風城崑劇團《牡丹亭》、《爛柯山》', 'displayCategory': '戲劇', 'imageUrl': 'https://s3.resource.opentix.life/upload/program/1774075394527zn1SFUOm8L.jpeg', 'startDateTime': 1787985000, 'endDateTime': 1788078600, 'maxPrice': 1200, 'minPrice': 300, 'ageRestriction': '7歲以上', 'cities': ['臺北'], 'events': [{'id': '2035245606806757376', 'startDateTime': 1787985000, 'endDateTime': 1787992200}, {'id': '2035250315553792000', 'startDateTime': 1788071400, 'endDateTime': 1788078600}]}, {'id': '2035332701663215617', 'departmentId': 0, 'name': '2026 王亭驊大提琴獨奏會', 'displayCategory': '音樂', 'imageUrl': 'https://s3.resource.opentix.life/upload/program/1774095829379GJ7Zh5EPgL.png', 'startDateTime': 1784460600, 'endDateTime': 1784466000, 'maxPrice': 600, 'minPrice': 400, 'ageRestriction': '3歲以上', 'cities': ['臺北'], 'events': [{'id': '2035333693578682369', 'startDateTime': 1784460600, 'endDateTime': 1784466000}]}, {'id': '2035375703416848385', 'departmentId': 0, 'name': '2026夏至愛樂 — 莫札特與台灣的相遇', 'displayCategory': '音樂', 'imageUrl': 'https://s3.resource.opentix.life/upload/program/1774862516740EhoKG83ovc.jpeg', 'startDateTime': 1785047400, 'endDateTime': 1785243600, 'maxPrice': 800, 'minPrice': 500, 'ageRestriction': '3歲以上', 'cities': ['臺北', '臺中'], 'events': [{'id': '2035376484697628673', 'startDateTime': 1785047400, 'endDateTime': 1785052800}, {'id': '2035697892516663296', 'startDateTime': 1785238200, 'endDateTime': 1785243600}]}, {'id': '2035978919460421633', 'departmentId': 0, 'name': '娛人時代《班會別鬧！》', 'displayCategory': '戲劇', 'imageUrl': 'https://s3.resource.opentix.life/upload/program/1775035306589VJLdLCBdnM.jpeg', 'startDateTime': 1778671800, 'endDateTime': 1797426000, 'maxPrice': 600, 'minPrice': 600, 'ageRestriction': '12歲以上', 'cities': ['臺北'], 'events': [{'id': '2035978921041059841', 'startDateTime': 1778671800, 'endDateTime': 1778677200}, {'id': '2036003434706984961', 'startDateTime': 1782300600, 'endDateTime': 1782306000}, {'id': '2036003772175753217', 'startDateTime': 1784115000, 'endDateTime': 1784120400}, {'id': '2036003964492980225', 'startDateTime': 1787743800, 'endDateTime': 1787749200}, {'id': '2036004142528602113', 'startDateTime': 1790767800, 'endDateTime': 1790773200}, {'id': '2036004327527505921', 'startDateTime': 1792582200, 'endDateTime': 1792587600}, {'id': '2036004550127607809', 'startDateTime': 1795001400, 'endDateTime': 1795006800}, {'id': '2036004733400858625', 'startDateTime': 1797420600, 'endDateTime': 1797426000}]}, {'id': '2035989296865427457', 'departmentId': 0, 'name': '2026關渡藝術節戲劇學院夏季公演《陶博智》', 'displayCategory': '戲劇', 'imageUrl': 'https://s3.resource.opentix.life/upload/program/1774252572402ShtvTZ2aRl.png', 'startDateTime': 1779449400, 'endDateTime': 1780216800, 'maxPrice': 1000, 'minPrice': 1000, 'ageRestriction': '12歲以上', 'cities': ['臺北'], 'events': [{'id': '2035990013148094465', 'startDateTime': 1779449400, 'endDateTime': 1779457200}, {'id': '2036 ...
# <class 'dict'>
# {'requestId': 'fd5ef0e5-1482-4430-995a-62998889944a', 'result': {'nextPage': 45, 'data': [{'id': '2034547591404400641', 'departmentId': 0, 'name': '2026 衛武營音樂營&歐洲銅管之聲 教師音樂會《自由揮灑》', 'displayCategory': '音樂', 'imageUrl': 'https://s3.resource.opentix.life/upload/program/17739187905838NTnluHUhs.png', 'startDateTime': 1783769400, 'endDateTime': 1783775100, 'maxPrice': 1200, 'minPrice': 500, 'filmRating': '普遍級', 'cities': ['高雄'], 'events': [{'id': '2034553038721073153', 'startDateTime': 1783769400, 'endDateTime': 1783775100}]}, {'id': '2034877460146262017', 'departmentId': 0, 'name': '2026瑞光樂集《追憶多瑙河畔》', 'displayCategory': '音樂', 'imageUrl': 'https://s3.resource.opentix.life/upload/program/1773987455836rXKOgL6SCg.jpeg', 'startDateTime': 1781850600, 'endDateTime': 1782219600, 'maxPrice': 800, 'minPrice': 300, 'ageRestriction': '5歲 (以上)', 'cities': ['臺中', '臺北'], 'events': [{'id': '2034878251594113024', 'startDateTime': 1781850600, 'endDateTime': 1781856000}, {'id': '2034910848353263617', 'startDateTime': 1782214200, 'endDateTime': 1782219600}]}, {'id': '2035245605008674817', 'departmentId': 0, 'name': '【崑劇】風城崑劇團《牡丹亭》、《爛柯山》', 'displayCategory': '戲劇', 'imageUrl': 'https://s3.resource.opentix.life/upload/program/1774075394527zn1SFUOm8L.jpeg', 'startDateTime': 1787985000, 'endDateTime': 1788078600, 'maxPrice': 1200, 'minPrice': 300, 'ageRestriction': '7歲以上', 'cities': ['臺北'], 'events': [{'id': '2035245606806757376', 'startDateTime': 1787985000, 'endDateTime': 1787992200}, {'id': '2035250315553792000', 'startDateTime': 1788071400, 'endDateTime': 1788078600}]}, {'id': '2035332701663215617', 'departmentId': 0, 'name': '2026 王亭驊大提琴獨奏會', 'displayCategory': '音樂', 'imageUrl': 'https://s3.resource.opentix.life/upload/program/1774095829379GJ7Zh5EPgL.png', 'startDateTime': 1784460600, 'endDateTime': 1784466000, 'maxPrice': 600, 'minPrice': 400, 'ageRestriction': '3歲以上', 'cities': ['臺北'], 'events': [{'id': '2035333693578682369', 'startDateTime': 1784460600, 'endDateTime': 1784466000}]}, {'id': '2035375703416848385', 'departmentId': 0, 'name': '2026夏至愛樂 — 莫札特與台灣的相遇', 'displayCategory': '音樂', 'imageUrl': 'https://s3.resource.opentix.life/upload/program/1774862516740EhoKG83ovc.jpeg', 'startDateTime': 1785047400, 'endDateTime': 1785243600, 'maxPrice': 800, 'minPrice': 500, 'ageRestriction': '3歲以上', 'cities': ['臺北', '臺中'], 'events': [{'id': '2035376484697628673', 'startDateTime': 1785047400, 'endDateTime': 1785052800}, {'id': '2035697892516663296', 'startDateTime': 1785238200, 'endDateTime': 1785243600}]}, {'id': '2035978919460421633', 'departmentId': 0, 'name': '娛人時代《班會別鬧！》', 'displayCategory': '戲劇', 'imageUrl': 'https://s3.resource.opentix.life/upload/program/1775035306589VJLdLCBdnM.jpeg', 'startDateTime': 1778671800, 'endDateTime': 1797426000, 'maxPrice': 600, 'minPrice': 600, 'ageRestriction': '12歲以上', 'cities': ['臺北'], 'events': [{'id': '2035978921041059841', 'startDateTime': 1778671800, 'endDateTime': 1778677200}, {'id': '2036003434706984961', 'startDateTime': 1782300600, 'endDateTime': 1782306000}, {'id': '2036003772175753217', 'startDateTime': 1784115000, 'endDateTime': 1784120400}, {'id': '2036003964492980225', 'startDateTime': 1787743800, 'endDateTime': 1787749200}, {'id': '2036004142528602113', 'startDateTime': 1790767800, 'endDateTime': 1790773200}, {'id': '2036004327527505921', 'startDateTime': 1792582200, 'endDateTime': 1792587600}, {'id': '2036004550127607809', 'startDateTime': 1795001400, 'endDateTime': 1795006800}, {'id': '2036004733400858625', 'startDateTime': 1797420600, 'endDateTime': 1797426000}]}, {'id': '2035989296865427457', 'departmentId': 0, 'name': '2026關渡藝術節戲劇學院夏季公演《陶博智》', 'displayCategory': '戲劇', 'imageUrl': 'https://s3.resource.opentix.life/upload/program/1774252572402ShtvTZ2aRl.png', 'startDateTime': 1779449400, 'endDateTime': 1780216800, 'maxPrice': 1000, 'minPrice': 1000, 'ageRestriction': '12歲以上', 'cities': ['臺北'], 'events': [{'id': '2035990013148094465', 'startDateTime': 1779449400, 'endDateTime': 1779457200}, {'id': '2036 ...
# <class 'dict'>
