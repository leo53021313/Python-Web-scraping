# %%
import requests

cookies = {
    'PHPSESSID': '04vrfh65re351fie0otnrkf3im',
    '_qg_fts': '1776924030',
    'QGUserId': '1715441481003744',
    '_qg_pushrequest': 'true',
    '_qg_cm': '1',
    'cf_clearance': 'Qe1gEGHkr5.elhfLCWCDmV9U5PkVDNGvwIk2U6OIl90-1776924028-1.2.1.1-DQBvfGZUGuKXIig7N_j8WN9GeUeuTdSDM0zwKHfqb1M095.u69s8CAvprQJC3j8exMaMx50r0.XURvfhCBpnXZUWhWSlLokxLnezN2Q0oUOcD_rUfdijxGd50GR2bHCagtCJCiaSGi.TEIfq4PyNgsdLxMN7b95t3LxTsgdIWHIlkQQ0HJeVLiFOi9panQM5FLtq118Y8hY45_mq1G5ajI6GX6sipzi_FOb2XQIAc01mUkSkE2ye0qzqN7xbGZfyFkS3v2f1RB6H3qgJmYEfPZvmsugMGU.RY4NrYkI25hQ6YdYn1yWvQ4pUeN3zctPqpftTY2LwItpAs_l899tCDA',
}

headers = {
    'accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.7',
    'accept-language': 'zh-TW,zh;q=0.9,en-US;q=0.8,en;q=0.7',
    'cache-control': 'max-age=0',
    'priority': 'u=0, i',
    'referer': 'https://hiking.biji.co/index.php?q=mountain&act=famous-list&id=1',
    'sec-ch-ua': '"Google Chrome";v="147", "Not.A/Brand";v="8", "Chromium";v="147"',
    'sec-ch-ua-mobile': '?0',
    'sec-ch-ua-platform': '"Windows"',
    'sec-fetch-dest': 'document',
    'sec-fetch-mode': 'navigate',
    'sec-fetch-site': 'same-origin',
    'sec-fetch-user': '?1',
    'upgrade-insecure-requests': '1',
    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/147.0.0.0 Safari/537.36',
    # 'cookie': 'PHPSESSID=04vrfh65re351fie0otnrkf3im; _qg_fts=1776924030; QGUserId=1715441481003744; _qg_pushrequest=true; _qg_cm=1; cf_clearance=Qe1gEGHkr5.elhfLCWCDmV9U5PkVDNGvwIk2U6OIl90-1776924028-1.2.1.1-DQBvfGZUGuKXIig7N_j8WN9GeUeuTdSDM0zwKHfqb1M095.u69s8CAvprQJC3j8exMaMx50r0.XURvfhCBpnXZUWhWSlLokxLnezN2Q0oUOcD_rUfdijxGd50GR2bHCagtCJCiaSGi.TEIfq4PyNgsdLxMN7b95t3LxTsgdIWHIlkQQ0HJeVLiFOi9panQM5FLtq118Y8hY45_mq1G5ajI6GX6sipzi_FOb2XQIAc01mUkSkE2ye0qzqN7xbGZfyFkS3v2f1RB6H3qgJmYEfPZvmsugMGU.RY4NrYkI25hQ6YdYn1yWvQ4pUeN3zctPqpftTY2LwItpAs_l899tCDA',
}

params = {
    'q': 'mountain',
    'act': 'famous-detail',
    'category': '1',
    'id': '1',
}

response = requests.get('https://hiking.biji.co/index.php', params=params, cookies=cookies, headers=headers)

print(response.text)
# Out:
# <!DOCTYPE html>
# <html lang="zh-TW">
#     <head>
#         <meta charset="utf-8">
#         <meta http-equiv="x-dns-prefetch-control" content="on">
#         <meta name="viewport" content="width=device-width, height=device-height, user-scalable=1">
#                 <meta name="dailymotion-domain-verification" content="dmg4s90bnv71te1dt">
#         <title>玉山主峰綜合資訊 - 健行筆記</title>
#         <meta name="description" content="玉山主峰位於台灣的中心位置，海拔3952公尺，為台灣群山之首，百岳排名第一，也是東北亞的最高峰。主峰四周有東、南、西、北峰環繞，外圍還有前峰、小南山、南玉山、東小南山、鹿山與北北峰遙相呼應，宛如眾星拱月般，襯托出主峰的王者之尊，壯偉雄...">
# <meta name="image" content="https://cdntwrunning.biji.co/600_eb085b82ef60e12a7ceef0f1d28b80f181349c7322533265283230a326f0cb00.jpg">
# <meta itemprop="name" content="玉山主峰綜合資訊"/>
# <meta itemprop="description" content="玉山主峰位於台灣的中心位置，海拔3952公尺，為台灣群山之首，百岳排名第一，也是東北亞的最高峰。主峰四周有東、南、西、北峰環繞，外圍還有前峰、小南山、南玉山、東小南山、鹿山與北北峰遙相呼應，宛如眾星拱月般，襯托出主峰的王者之尊，壯偉雄..."/>
# ...
